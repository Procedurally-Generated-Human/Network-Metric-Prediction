# %%
import algorithms, helpers
import torch
import torch.nn as nn

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = helpers.load_puffer_dataset()
qs = [0.25, 0.75]
horizons=[1, 2, 4, 8, 16]
n_lags=10
sample_size=800000
base_features = ['cwnd', 'in_flight', 'min_rtt', 'rtt', 'delivery_rate', 'buffer']

# %%
for metric in ['rtt', 'delivery_rate']:
    algorithms.run_basic_models_comparison(df, feature_cols=base_features, target_metric=metric, n_lags=5, sample_size=sample_size, horizons=horizons, save_plots=True)
# Out:
# Preparing dataset for target='rtt', lags=5, Horizon=1
# Num training windows : 638052, Num testing windows : 159156
# Training LSTM
#  Epoch 1/100 | Train Loss: 0.090140
#  Epoch 2/100 | Train Loss: 0.060292
#  Epoch 3/100 | Train Loss: 0.058710
#  Epoch 4/100 | Train Loss: 0.057927
#  Epoch 5/100 | Train Loss: 0.057369
#  Epoch 6/100 | Train Loss: 0.056940
#  Epoch 7/100 | Train Loss: 0.056602
#  Epoch 8/100 | Train Loss: 0.056281
#  Epoch 9/100 | Train Loss: 0.056035
#  Epoch 10/100 | Train Loss: 0.055807
#  Epoch 11/100 | Train Loss: 0.055568
#  Epoch 12/100 | Train Loss: 0.055383
#  Epoch 13/100 | Train Loss: 0.055223
#  Epoch 14/100 | Train Loss: 0.055071
#  Epoch 15/100 | Train Loss: 0.054934
#  Epoch 16/100 | Train Loss: 0.054834
#  Epoch 17/100 | Train Loss: 0.054708
#  Epoch 18/100 | Train Loss: 0.054597
#  Epoch 19/100 | Train Loss: 0.054541
#  Epoch 20/100 | Train Loss: 0.054428
#  Epoch 21/100 | Train Loss: 0.054336
#  Epoch 22/100 | Train Loss: 0.054261
#  Epoch 23/100 | Train Loss: 0.054189
#  Epoch 24/100 | Train Loss: 0.054109
#  Epoch 25/100 | Train Loss: 0.054042
#  Epoch 26/100 | Train Loss: 0.054023
#  Epoch 27/100 | Train Loss: 0.053887
#  Epoch 28/100 | Train Loss: 0.053939
# Training catboost
# 0:	learn: 0.6303145	test: 0.3838274	best: 0.3838274 (0)	total: 264ms	remaining: 8m 47s
# 200:	learn: 0.1376052	test: 0.1544270	best: 0.1544270 (200)	total: 21.1s	remaining: 3m 8s
# 400:	learn: 0.1348144	test: 0.1532416	best: 0.1532416 (400)	total: 42.8s	remaining: 2m 50s
# 600:	learn: 0.1332185	test: 0.1526131	best: 0.1526079 (583)	total: 1m 3s	remaining: 2m 26s
# 800:	learn: 0.1320259	test: 0.1521458	best: 0.1521423 (798)	total: 1m 22s	remaining: 2m 3s
# 1000:	learn: 0.1311030	test: 0.1518585	best: 0.1518535 (984)	total: 1m 42s	remaining: 1m 42s
# 1200:	learn: 0.1302371	test: 0.1516523	best: 0.1516381 (1195)	total: 2m 2s	remaining: 1m 21s
# 1400:	learn: 0.1295137	test: 0.1516139	best: 0.1516139 (1400)	total: 2m 22s	remaining: 1m
# 1600:	learn: 0.1288275	test: 0.1516252	best: 0.1516007 (1427)	total: 2m 41s	remaining: 40.4s
# 1800:	learn: 0.1281710	test: 0.1515482	best: 0.1515429 (1777)	total: 3m 1s	remaining: 20s
# 1999:	learn: 0.1275883	test: 0.1515299	best: 0.1515208 (1986)	total: 3m 20s	remaining: 0us
#
# bestTest = 0.1515208192
# bestIteration = 1986
#
# Shrink model to first 1987 iterations.
# Training MLP
# Iteration 1, loss = 0.16153026
# Validation score: 0.612990
# Iteration 2, loss = 0.15590643
# Validation score: 0.616038
# Iteration 3, loss = 0.15379691
# Validation score: 0.617343
# Iteration 4, loss = 0.15207925
# Validation score: 0.616882
# Iteration 5, loss = 0.15086340
# Validation score: 0.616678
# Iteration 6, loss = 0.15364717
# Validation score: 0.614691
# Iteration 7, loss = 0.15142961
# Validation score: 0.611762
# Iteration 8, loss = 0.15399135
# Validation score: 0.615827
# Iteration 9, loss = 0.15118403
# Validation score: 0.611595
# Iteration 10, loss = 0.15489833
# Validation score: 0.613034
# Iteration 11, loss = 0.15061603
# Validation score: 0.619467
# Iteration 12, loss = 0.15080408
# Validation score: 0.612978
# Iteration 13, loss = 0.15169676
# Validation score: 0.615752
# Iteration 14, loss = 0.15144051
# Validation score: 0.617147
# Iteration 15, loss = 0.15046216
# Validation score: 0.618453
# Iteration 16, loss = 0.14991083
# Validation score: 0.612430
# Iteration 17, loss = 0.15227246
# Validation score: 0.615165
# Iteration 18, loss = 0.15075954
# Validation score: 0.615525
# Iteration 19, loss = 0.14916754
# Validation score: 0.589598
# Iteration 20, loss = 0.14931650
# Validation score: 0.615610
# Iteration 21, loss = 0.15098929
# Validation score: 0.619498
# Iteration 22, loss = 0.15010031
# Validation score: 0.618824
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training GRU
#  Epoch 1/100 | Train Loss: 0.378095
#  Epoch 2/100 | Train Loss: 0.326410
#  Epoch 3/100 | Train Loss: 0.322943
#  Epoch 4/100 | Train Loss: 0.321758
#  Epoch 5/100 | Train Loss: 0.320574
#  Epoch 6/100 | Train Loss: 0.319359
#  Epoch 7/100 | Train Loss: 0.318398
#  Epoch 8/100 | Train Loss: 0.315889
#  Epoch 9/100 | Train Loss: 0.315474
#  Epoch 10/100 | Train Loss: 0.314769
#  Epoch 11/100 | Train Loss: 0.313033
#  Epoch 12/100 | Train Loss: 0.311773
#  Epoch 13/100 | Train Loss: 0.310771
#  Epoch 14/100 | Train Loss: 0.308999
#  Epoch 15/100 | Train Loss: 0.308763
#  Epoch 16/100 | Train Loss: 0.306870
#  Epoch 17/100 | Train Loss: 0.305527
#  Epoch 18/100 | Train Loss: 0.306254
#  Epoch 19/100 | Train Loss: 0.304811
#  Epoch 20/100 | Train Loss: 0.303888
#  Epoch 21/100 | Train Loss: 0.303238
#  Epoch 22/100 | Train Loss: 0.301756
#  Epoch 23/100 | Train Loss: 0.302025
#  Epoch 24/100 | Train Loss: 0.300148
#  Epoch 25/100 | Train Loss: 0.299766
#  Epoch 26/100 | Train Loss: 0.298609
#  Epoch 27/100 | Train Loss: 0.297817
#  Epoch 28/100 | Train Loss: 0.298673
#  Epoch 29/100 | Train Loss: 0.296709
#  Epoch 30/100 | Train Loss: 0.295170
#  Epoch 31/100 | Train Loss: 0.293488
#  Epoch 32/100 | Train Loss: 0.293514
#  Epoch 33/100 | Train Loss: 0.293115
#  Epoch 34/100 | Train Loss: 0.293233
#  Epoch 35/100 | Train Loss: 0.289730
#  Epoch 36/100 | Train Loss: 0.289515
#  Epoch 37/100 | Train Loss: 0.289961
#  Epoch 38/100 | Train Loss: 0.290043
#  Epoch 39/100 | Train Loss: 0.288918
#  Epoch 40/100 | Train Loss: 0.288983
#  Epoch 7/100 | Train Loss: 0.057569
#  Epoch 8/100 | Train Loss: 0.057312
#  Epoch 9/100 | Train Loss: 0.057077
#  Epoch 10/100 | Train Loss: 0.056883
#  Epoch 11/100 | Train Loss: 0.056666
#  Epoch 12/100 | Train Loss: 0.056475
#  Epoch 13/100 | Train Loss: 0.056379
#  Epoch 14/100 | Train Loss: 0.056226
#  Epoch 15/100 | Train Loss: 0.056098
#  Epoch 16/100 | Train Loss: 0.056008
#  Epoch 17/100 | Train Loss: 0.055874
#  Epoch 18/100 | Train Loss: 0.055771
#  Epoch 19/100 | Train Loss: 0.055693
#  Epoch 20/100 | Train Loss: 0.055616
#  Epoch 21/100 | Train Loss: 0.055586
#  Epoch 22/100 | Train Loss: 0.055545
#  Epoch 23/100 | Train Loss: 0.055486
# Training catboost
# 0:	learn: 0.6303430	test: 0.3837051	best: 0.3837051 (0)	total: 97.8ms	remaining: 3m 15s
# 200:	learn: 0.1396472	test: 0.1583093	best: 0.1583093 (200)	total: 19.2s	remaining: 2m 51s
# 400:	learn: 0.1370144	test: 0.1574663	best: 0.1574659 (399)	total: 38.2s	remaining: 2m 32s
# 600:	learn: 0.1356080	test: 0.1570151	best: 0.1570151 (600)	total: 57.3s	remaining: 2m 13s
# 800:	learn: 0.1346297	test: 0.1567919	best: 0.1567919 (800)	total: 1m 16s	remaining: 1m 54s
# 1000:	learn: 0.1338003	test: 0.1565659	best: 0.1565646 (993)	total: 1m 35s	remaining: 1m 34s
# 1200:	learn: 0.1330173	test: 0.1563837	best: 0.1563837 (1200)	total: 1m 54s	remaining: 1m 16s
# 1400:	learn: 0.1323599	test: 0.1562739	best: 0.1562739 (1400)	total: 2m 13s	remaining: 57.2s
# 1600:	learn: 0.1318505	test: 0.1562024	best: 0.1561937 (1559)	total: 2m 32s	remaining: 38s
# 1800:	learn: 0.1313619	test: 0.1561551	best: 0.1561549 (1797)	total: 2m 51s	remaining: 18.9s
# 1999:	learn: 0.1308332	test: 0.1561075	best: 0.1560972 (1859)	total: 3m 10s	remaining: 0us
#
# bestTest = 0.1560972318
# bestIteration = 1859
#
# Shrink model to first 1860 iterations.
# Training MLP
# Iteration 1, loss = 0.17346849
# Validation score: 0.715235
# Iteration 2, loss = 0.16887002
# Validation score: 0.716910
# Iteration 3, loss = 0.16751146
# Validation score: 0.720321
# Iteration 4, loss = 0.16895998
# Validation score: 0.718838
# Iteration 5, loss = 0.16722281
# Validation score: 0.716096
# Iteration 6, loss = 0.16808691
# Validation score: 0.716382
# Iteration 7, loss = 0.16671621
# Validation score: 0.708512
# Iteration 8, loss = 0.16689310
# Validation score: 0.718450
# Iteration 9, loss = 0.16671291
# Validation score: 0.719234
# Iteration 10, loss = 0.16595646
# Validation score: 0.717343
# Iteration 11, loss = 0.16661780
# Validation score: 0.719584
# Iteration 12, loss = 0.16677182
# Validation score: 0.715723
# Iteration 13, loss = 0.16730759
# Validation score: 0.715634
# Iteration 14, loss = 0.17070099
# Validation score: 0.716609
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#
#  Epoch 74/100 | Train Loss: 0.278709
#  Epoch 75/100 | Train Loss: 0.277700
#  Epoch 76/100 | Train Loss: 0.277792
#  Epoch 77/100 | Train Loss: 0.277062
#  Epoch 78/100 | Train Loss: 0.274966
#  Epoch 79/100 | Train Loss: 0.278097
#  Epoch 80/100 | Train Loss: 0.274898
#  Epoch 81/100 | Train Loss: 0.275676
#  Epoch 82/100 | Train Loss: 0.273953
#  Epoch 83/100 | Train Loss: 0.274268
#  Epoch 84/100 | Train Loss: 0.275872
#  Epoch 85/100 | Train Loss: 0.272506
#  Epoch 86/100 | Train Loss: 0.272699
#  Epoch 87/100 | Train Loss: 0.272933
#  Epoch 88/100 | Train Loss: 0.274471
#  Epoch 89/100 | Train Loss: 0.272510
#  Epoch 90/100 | Train Loss: 0.273316
#  Epoch 91/100 | Train Loss: 0.271128
#  Epoch 92/100 | Train Loss: 0.270802
#  Epoch 93/100 | Train Loss: 0.270882
#  Epoch 94/100 | Train Loss: 0.272493
#  Epoch 95/100 | Train Loss: 0.269474
#  Epoch 96/100 | Train Loss: 0.271804
#  Epoch 97/100 | Train Loss: 0.270022
#  Epoch 98/100 | Train Loss: 0.270321
#  Epoch 99/100 | Train Loss: 0.269427
#  Epoch 100/100 | Train Loss: 0.269190
# Preparing dataset for target='rtt', lags=5, Horizon=4
# Num training windows : 637128, Num testing windows : 158756
# Training LSTM
#  Epoch 1/100 | Train Loss: 0.091990
#  Epoch 2/100 | Train Loss: 0.062343
#  Epoch 3/100 | Train Loss: 0.060874
#  Epoch 4/100 | Train Loss: 0.059944
#  Epoch 5/100 | Train Loss: 0.059317
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 for metric in ['rtt', 'delivery_rate']:
# ----> 2     algorithms.run_basic_models_comparison(df, feature_cols=base_features, target_metric=metric, n_lags=5, sample_size=sample_size, horizons=horizons, save_plots=True)
#
# File c:\Users\uylon\COMP6321-Project\Network-Metric-Prediction\src\algorithms.py:896, in run_basic_models_comparison(df, feature_cols, target_metric, n_lags, sample_size, horizons, save_plots)
#     886 gru_model_param={
#     887     'model': gru_model_basic,
#     888     'batch_size': 512,
#    (...)
#     892     'device': torch.device("cuda" if torch.cuda.is_available() else "cpu")
#     893 }
#     895 print(f"Training LSTM")
# --> 896 lstm_model, lstm_data = train_lstm_timeseries(train_windows_ds, test_windows_ds, basic_model_param)
#     897 all_preds['lstm'][i] = lstm_data.get('y_pred_test', None)
#     898 all_train_mae['lstm'].append(lstm_data.get('train_mae', None))
#
# File c:\Users\uylon\COMP6321-Project\Network-Metric-Prediction\src\algorithms.py:247, in train_lstm_timeseries(train_ds, test_ds, model_param)
#     245 y_pred = model(x_batch).squeeze(-1)
#     246 loss = objective(y_pred, y_batch)
# --> 247 loss.backward()
#     248 torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
#     249 optimizer.step()
#
# File c:\Users\uylon\anaconda\envs\pytorch-gpu\lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\Users\uylon\anaconda\envs\pytorch-gpu\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Users\uylon\anaconda\envs\pytorch-gpu\lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
qs = [0.25, 0.75]
horizons=[1, 4, 16]
for metric in ['rtt', 'delivery_rate']:
    algorithms.run_quantile_models_comparison(df, feature_cols=base_features, target_metric=metric, n_lags=5, sample_size=sample_size, horizons=horizons, qs = qs, save_plots = True)
